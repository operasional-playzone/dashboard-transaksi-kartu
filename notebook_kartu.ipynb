# %% [markdown]
# # Notebook Transaksi Kartu Ramayana Makmur Sentosa Playzone Tahun 2024 - 2025

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px  # Kita pakai Plotly agar grafik interaktif (cocok buat Streamlit)
import re
import matplotlib.ticker as ticker
import plotly.graph_objects as go

# %% [markdown]
# Load Data

# %%
# Konfigurasi tampilan pandas
pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format

# LOAD DATA
# Pastikan file ini adalah hasil output dari script terakhir Anda
file_path = "DETAIL_PAKET_TRANSAKSI_GABUNGAN.xlsx"
df = pd.read_excel(file_path)

print(f"Data Loaded: {df.shape[0]} baris, {df.shape[1]} kolom")
df.head()
# Out:
# Data Loaded: 38918 baris, 9 kolom
#          Folder_Asal  Nama_Toko_Internal  Tahun    Bulan   Tipe_Kartu  \
# 0  R015 Dewi Sartika  Dewi Sartika Bogor   2024  Januari  Kiddie Land
# 1  R015 Dewi Sartika  Dewi Sartika Bogor   2024  Januari  Kiddie Land
# 2  R015 Dewi Sartika  Dewi Sartika Bogor   2024  Januari  Kiddie Land
# 3  R015 Dewi Sartika  Dewi Sartika Bogor   2024  Januari  Kiddie Land
# 4  R015 Dewi Sartika  Dewi Sartika Bogor   2024  Januari  Kiddie Land
#
#                                      Paket  Frekuensi  Total_Sales  \
# 0    FINTECH KIDDIE ZONE WEEKEND SEPUASNYA          2        90000
# 1          KIDDIE ZONE WEEKDAY 1 JAM + KKP         68      2040000
# 2      KIDDIE ZONE WEEKDAY SEPUASNYA + KKP         17       680000
# 3      KIDDIE ZONE WEEKEND 1 JAM + KK ANAK        330     11550000
# 4  KIDDIE ZONE WEEKEND SEPUASNYA + KK ANAK        107      4815000
#
#    Masuk_Kredit
# 0         90000
# 1       2040000
# 2        680000
# 3      11550000
# 4       4815000

# %% [markdown]
# * Folder_Asal = Nama Toko Standar
# * Nama_Toko_Internal = Nama Toko di Server
# * Tahun = Tahun transaksi kartu terjadi
# * Bulan = Bulan transaksi kartu terjadi
# * Paket = Nama paket top up kartu playzone
# * Frekuensi = Banyaknya transaksi yang terjadi pada suatu paket
# * Total_Sales = Jumlah pendapatan dari paket yang terjual
# * Masuk_Kredit = Jumlah kredit yang masuk ke kartu dari paket yang dibeli oleh pembeli

# %% [markdown]
# Assesing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38918 entries, 0 to 38917
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Folder_Asal         38918 non-null  object
#  1   Nama_Toko_Internal  38918 non-null  object
#  2   Tahun               38918 non-null  int64
#  3   Bulan               38918 non-null  object
#  4   Tipe_Kartu          38918 non-null  object
#  5   Paket               38918 non-null  object
#  6   Frekuensi           38918 non-null  int64
#  7   Total_Sales         38918 non-null  int64
#  8   Masuk_Kredit        38918 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 2.7+ MB

# %% [markdown]
# Dataframe df memiliki 37582 entry data. Setiap kolom memiliki jumlah yang sama sehingga tidak ada data yang hilang. Untuk kolom tahun dan bulan masih berbentuk integer dan object sehingga perlu preprocessing menjadi datetime agar dapat difilter nantinya.

# %% [markdown]
# *Pemeriksaan parameter statistik*

# %%
df.describe()
# Out:
#           Tahun  Frekuensi    Total_Sales   Masuk_Kredit
# count 38,918.00  38,918.00      38,918.00      38,918.00
# mean   2,024.51     100.44   2,276,528.92   4,861,461.16
# std        0.50     226.39   7,566,225.55  11,739,165.16
# min    2,024.00       1.00           0.00           0.00
# 25%    2,024.00       4.00           0.00     200,000.00
# 50%    2,025.00      22.00      25,000.00   1,036,000.00
# 75%    2,025.00      93.00   1,148,000.00   4,392,000.00
# max    2,025.00   5,837.00 193,200,000.00 291,850,000.00

# %% [markdown]
# Kolom Total_Sales dan Masuk_Kredit memiliki null (0) value sehingga perlu diproses karena akan mengakibatkan kesalahan dalam visualisasi dan analisis.

# %% [markdown]
# ## Data Cleaning & Preprocessing

# %% [markdown]
# Pemeriksaan duplikasi

# %%
print("Jumlah data duplikat dari df:", df.duplicated().sum())
# Out:
# Jumlah data duplikat dari df: 75

# %% [markdown]
# Ada data duplikat, maka perlu dihandle.

# %%
df_clean = df.drop_duplicates()

# %% [markdown]
# Cek kembali duplikat.

# %%
print("Jumlah data duplikat dari df setelah dihandle:", df_clean.duplicated().sum())
# Out:
# Jumlah data duplikat dari df setelah dihandle: 0

# %% [markdown]
# Handle missing values

# %%
cols_numeric = ['Frekuensi', 'Total_Sales', 'Masuk_Kredit']
df_clean[cols_numeric] = df_clean[cols_numeric].fillna(0)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\4066378391.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Hapus value yang pada kolom total_sales dan masuk_kredit dua duanya 0

# %%
# Cek jumlah baris awal
print(f"Total Baris Awal: {len(df_clean)}")

# LOGIKA FILTERING:
# Ambil baris HANYA JIKA (Total_Sales TIDAK 0) ATAU (Masuk_Kredit TIDAK 0)
# Tanda | berarti "ATAU"
df_clean = df_clean[
    (df_clean['Total_Sales'] != 0) | 
    (df_clean['Masuk_Kredit'] != 0)
].copy()

# Cek hasil setelah dibuang
print(f"Total Baris Bersih: {len(df_clean)}")
# Out:
# Total Baris Awal: 38843
# Total Baris Bersih: 36949

# %% [markdown]
# Buat Kolom Omset_Paket

# %%
#Ambil Total_Sales. Jika 0, baru ambil Masuk_Kredit.
df_clean['Omset_Paket'] = np.where(
    df_clean['Total_Sales'] != 0,  # Kondisi: Apakah Sales ada isinya?
    df_clean['Total_Sales'],       # Jika YA: Ambil Sales
    df_clean['Masuk_Kredit']       # Jika TIDAK: Ambil Kredit
)

# Cek hasil untuk memastikan tidak ada penjumlahan
print("✅ Kolom 'Omset_Paket' berhasil diperbarui (Logika Tempel).")
print("\nSampel Data (Cek variasi nilai):")
display(df_clean[['Paket', 'Total_Sales', 'Masuk_Kredit', 'Omset_Paket']].sample(10))
# Out:
# ✅ Kolom 'Omset_Paket' berhasil diperbarui (Logika Tempel).
#
# Sampel Data (Cek variasi nilai):
#                                             Paket  Total_Sales  Masuk_Kredit  \
# 37971  PAKET BUNDLING 100Rbu + 2 TBK + BONUS 100%     31406000      31406000
# 26002                 MEGASALE 200rb + BONUS 150%       200000        200000
# 26502     Mega Sale Rp.150 Rb TTL 535 Poin (150%)       300000        300000
# 12496        ISI ULANG ZONE Rp.30 Rb s/d Rp.49 Rb            0        435000
# 34155       PAKET ISI ULANG 50K 15%+ ICE CONE(9K)            0        123000
# 4516                        NEW DEBIT BCA 100.000            0       1200000
# 2233       ISI ULANG PLAYGROUND SEPUASNYA WEEKEND            0         50000
# 1104     PAKET BUNDLING 50Rbu + NUGET + BONUS 15%       420000        420000
# 19182            New kiddie Land Weekdays (1 JAM)        85000         84800
# 24911                 50RB BANDLING ICE CREAM CUP      3496000       3496000
#
#        Omset_Paket
# 37971     31406000
# 26002       200000
# 26502       300000
# 12496       435000
# 34155       123000
# 4516       1200000
# 2233         50000
# 1104        420000
# 19182        85000
# 24911      3496000

# %% [markdown]
# Mengecek informasi umum dataframe setelah dilakukan penanganan data duplikat

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36949 entries, 0 to 38916
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Folder_Asal         36949 non-null  object
#  1   Nama_Toko_Internal  36949 non-null  object
#  2   Tahun               36949 non-null  int64
#  3   Bulan               36949 non-null  object
#  4   Tipe_Kartu          36949 non-null  object
#  5   Paket               36949 non-null  object
#  6   Frekuensi           36949 non-null  int64
#  7   Total_Sales         36949 non-null  int64
#  8   Masuk_Kredit        36949 non-null  int64
#  9   Omset_Paket         36949 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 3.1+ MB

# %% [markdown]
# Terdapat pengurangan banyaknya data menjadi 35638

# %% [markdown]
# Cleaning data waktu agar datetime

# %% [markdown]
# Mapping Bulan dan Tahun ke Tanggal (datetime) agar mudah dikategorikan

# %%
# Standardisasi Nama Bulan ---
# Pastikan nama bulan konsisten (Title Case: Januari, bukan januari)
# Menggunakan df_clean
df_clean['Bulan'] = df_clean['Bulan'].astype(str).str.title()

# Mapping Bulan Indonesia ke Angka (Untuk bikin tanggal)
map_bulan = {
    'Januari': 1, 'Februari': 2, 'Maret': 3, 'April': 4,
    'Mei': 5, 'Juni': 6, 'Juli': 7, 'Agustus': 8,
    'September': 9, 'Oktober': 10, 'November': 11, 'Desember': 12
}

df_clean['Bulan_Angka'] = df_clean['Bulan'].map(map_bulan)

# Membuat Kolom Tanggal (Date) ---
# Kita set tanggal 1 sebagai default karena data kita bulanan
# Menggunakan df_clean.Tahun dan df_clean.Bulan_Angka
df_clean['Tanggal'] = pd.to_datetime(dict(year=df_clean.Tahun, month=df_clean.Bulan_Angka, day=1))

# Filter Data Aneh (Optional) ---
# Contoh: Hapus jika Total_Sales negatif (jika perlu)
# df_clean = df_clean[df_clean['Total_Sales'] >= 0] 

print("Rentang Data:", df_clean['Tanggal'].min(), "sampai", df_clean['Tanggal'].max())
df_clean.info()
# Out:
# Rentang Data: 2024-01-01 00:00:00 sampai 2025-12-01 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# Index: 36949 entries, 0 to 38916
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Folder_Asal         36949 non-null  object
#  1   Nama_Toko_Internal  36949 non-null  object
#  2   Tahun               36949 non-null  int64
#  3   Bulan               36949 non-null  object
#  4   Tipe_Kartu          36949 non-null  object
#  5   Paket               36949 non-null  object
#  6   Frekuensi           36949 non-null  int64
#  7   Total_Sales         36949 non-null  int64
#  8   Masuk_Kredit        36949 non-null  int64
#  9   Omset_Paket         36949 non-null  int64
#  10  Bulan_Angka         36949 non-null  int64
#  11  Tanggal             36949 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 3.7+ MB

# %% [markdown]
# Mapping Kategori Paket

# %%
print("\n=== FREKUENSI PAKET ===")
pd.set_option('display.max_rows', None) # Agar bisa scroll sampai bawah
display(df_clean['Paket'].value_counts())
pd.reset_option('display.max_rows') # Kembalikan ke setting awal
# Out:
# === FREKUENSI PAKET ===
# Paket
# PAKET KARTU 30Rbu                                     206
# PAKET KARTU 50Rbu + BONUS 30%                         187
# PAKET KARTU KIDDIELAND SEPUASNYA                      186
# PAKET KARTU 100Rbu + BONUS 50%                        179
# PAKET KARTU 50rb + BONUS 15% + 2 SOSRO                178
# PAKET KARTU 100rb + BONUS 100% + 4 SOSRO              164
# PAKET KARTU 50rb + BONUS 100% + 2 SOSRO               164
# PAKET KARTU 25Rbu                                     158
# PAKET KARTU KIDDIELAND SEPUASNYA WEEKEND              151
# Isi Ulang Zone Rp.30 Rb s/d Rp.49 Rb                  149
# PAKET KARTU KIDDIELAND 1 JAM WEEKDAY                  147
# PAKET KARTU KIDDIELAND 1 JAM WEEKEND                  135
# PAKET BUNDLING 50Rbu + SOSRO + BONUS 15%              123
# PAKET KARTU 30rb + BONUS 15% + 1 SOSRO                122
# Isi Ulang Zone Rp.10 Rb s/d Rp.29 Rb                  107
# PAKET KARTU 50Rbu + Bonus 100%                        100
# MEGASALE 200rb + BONUS 150%                           100
# PAKET KARTU 30K                                        96
# PAKET KARTU 50rb + BONUS 30%                           93
# PAKET KARTU 50Rbu QPON                                 93
# PAKET KARTU 100rb + BONUS 50%                          87
# PAKET BUNDLING 50Rbu + POP CORN + BONUS 15%            83
# PAKET BUNDLING 100Rbu + SOSRO + BONUS 80%              80
# Isi Ulang Zone Rp.50 Rb s/d Rp.99 Rb                   75
# PAKET KARTU 50rb + BONUS 15% + SOSRO                   71
# PAKET KARTU 100rb + BONUS 80% + SOSRO                  70
# KARTU BARU ZONE Rp.50 Rb s/d Rp.99 Rb                  65
# PAKET KARTU 20Rbu QPON                                 58
# PAKET KARTU 15K                                        55
# PAKET BUNDLING 50Rbu + MINERAL + BONUS 15%             55
# ISI ULANG ZONE Rp.50 Rb s/d Rp.99 Rb                   54
# ISI ULANG KIDDIELAND WEEKDAY 1 JAM                     53
# New Zone Rp.30 Rb s/d Rp.49 Rb                         51
# PAKET KARTU 200rb + BONUS 200%                         51
# Isi Ulang Zone Rp.100 Rb s/d Rp.499 Rb                 50
# PAKET BUNDLING 100Rbu + POP CORN + BONUS 80%           48
# PAKET BUNDLING 50Rbu + NUGET + BONUS 15%               46
# PAKET KARTU 100Rbu TIKET.COM                           45
# Isi Ulang Zone Rp.2 Rb s/d Rp.49 Rb                    45
# MEGASALE 200rb BONUS 150%                              45
# KARTU BARU ZONE Rp.100 Rb s/d Rp.499 Rb                44
# ISI ULANG KARTU 10 - 49RB                              44
# PAKET BUNDLING 50Rbu + ICE CONE + 15%                  44
# PAKET BUNDLING 50Rbu + SOSIS + BONUS 15%               42
# ISI ULANG KIDDIELAND WEEKEND 1 JAM                     42
# PAKET KARTU 100rb + BONUS 100% + 2 SOSRO               41
# ISI ULANG KARTU 50 - 99RB BONUS 10%                    39
# Isi Ulang Zone Rp.2Rb s/d Rp.49Rb                      39
# Isi Ulang Zone Rp.10rb - Rp.49rb                       39
# PAKET BUNDLING 50Rbu + BAKSO + BONUS 15%               39
# Isi Ulang Zone Rp.10 Rb s/d Rp.49 Rb                   39
# ISI ULANG SALDO Rp.1.000 s/d Rp.49.000                 38
# ISI ULANG Rp50.000                                     37
# ISI ULANG Rp50.000 + PLAY CAFE                         37
# PAKET KARTU 100rb + BONUS 200%                         36
# Isi Ulang Zone Rp.50 Rb s/d Rp.99 Rb Bonus 30%         36
# Isi Ulang Zone Rp 5Rb s/d Rp 29Rb                      36
# PAKET BUNDLING 50Rbu + DUMPLING KEJU + BONUS 15%       35
# PAKET BUNDLING 50K + ICE CONE                          35
# PAKET BUNDLING 100Rbu + MINERAL + BONUS 80%            34
# PAKET BUNDLING 50Rbu + SALMON BALL + BONUS 15%         34
# Isi Ulang 50rb                                         33
# Isi ulang 50rb-99rb                                    33
# NEW KIDDIELAND WEEKEND 1 JAM                           33
# 50.000 BONUS SOSRO                                     32
# ISI ULANG 150K BONUS 50%                               32
# Isi Ulang Zone Rp.5 Rb s/d Rp.29 Rb                    32
# Isi Ulang Zone 20rb s/d 49rb                           31
# Isi Ulang Zone Rp.50 s/d Rp.99                         31
# PAKET BUNDLING 50Rbu + LOBSTER BALL + BONUS 15%        31
# ISI ULANG 35 RIBU                                      31
# ISI ULANG  30 RBU s/d 49 RBU                           31
# PAKET BUNDLING 50Rbu + KENTANG + BONUS 15%             30
# Isi Ulang Rp.10rb - Rp.49rb                            30
# Kartu Baru Zone Rp.50 Rb s/d Rp.99 Rb                  30
# ISI ULANG Rp.100.000                                   30
# ISI ULANG  Rp100.000 + PLAYCAFE                        29
# KIDDIE ZONE SEPUASNYA WEEKEND                          29
# Isi ulang 50000                                        29
# KIDDIE ZONE WEEKDAY SEPUASNYA                          29
# PAKET KARTU SEPUASNYA                                  29
# Isi Ulang Zone Rp100 s/d Rp499                         28
# KARTU ISI ULANG Rp.5 RB s/d Rp.49 RB                   28
# PAKET KARTU 50rb + BONUS 80% + SOSRO                   28
# NEW 35 RIBU                                            28
# Isi Ulang Rp.100 rb                                    28
# ISI ULANG EVEN                                         28
# ISI ULANG ZONE 30 RB s/d 49 RB                         28
# PAKET KARTU 50rb + BONUS 15%                           28
# PAKET BUNDLING 50K+SOSIS                               28
# BUNDLING 50K + PRIMA 2 pcs                             27
# PAKET BUNDLING 50K + TEH KOTAK                         27
# ISI ULANG ZONE Rp. 20 Rb s/d Rp.29 Rb                  27
# Isi Ulang Zone Rp.100 Rb s/d Rp.499 Rb Bonus 50%       27
# ISI ULANG ZONE Rp.15 Rb s/d Rp.49 Rb                   27
# KARTU ISI ULANG Rp.50 RB BONUS Rp.15 RB                27
# ISI ULANG 50RB BONUS POPCRON                           27
# ISI ULANG 150.000 50%                                  27
# KIDDIE ZONE WEEKDAY 1 JAM                              27
# PAKET KARTU KL SEJAM                                   27
# Isi Ulang Rp 5rb s/d Rp 29rb                           27
# PAKET SALDO ISI ULANG Rp.50RB BNS MKNN/MNMN            27
# PAKET BUNDLING 100Rbu + ICE CONE + BONUS 80%           26
# Isi Ulang 50rb bonus SOSRO                             26
# PAKET KARTU 30rb + BONUS 15% + SOSRO                   26
# Kartu Baru / Isi Ulang Zone Rp.10 K s/d Rp.49 K        26
# Kartu Baru / Isi Ulang Rp 30.000 Sd Rp 49.000          26
# ISI ULANG KIDDIELAND WEEKEND SEPUASNYA                 26
# PAKET KARTU 200Rbu TIKET.COM                           26
# PAKET BUNDLING 50K + LOBSTER BALL                      26
# PAKET 100K                                             26
# 50.000 BONUS BAKSO GORENG                              26
# Kartu Baru Zone Rp.30 Rb s/d Rp.49 Rb                  25
# PAKET BUNDLING 100Rbu + SOSIS + BONUS 15%              25
# PAKET BUNDLING 50Rbu + POP MIE + BONUS 15%             25
# Isi Ulang Zone Rp.100 Rb s/d Rp.499 Rb Bonus 100%      25
# PAKET KARTU BARU Rp.50RB BONUS MKNN / MINUMAN          24
# Rp. 35.000 (Jml Poin 50)                               24
# NEW EVEN                                               24
# Beli 50K Bonus 10%                                     24
# PROMO SOSRO Rp.50 Rb FREE 2 PCS SOSRO 200 ML           24
# Isi Ulang/Kartu Baru Rp 50rb s/d Rp 99 Rb              24
# KARTU BARU Rp.50 Rb BONUS Rp.15 RB                     24
# PAKET KARTU ZONE Rp.100.000 - Rp. 149.000              23
# PAKET BUNDLING 100Rbu + NUGET + BONUS 80%              23
# Isi Ulang Zone Rp 100 s/d Rp 499                       23
# KARTU ISI ULANG Rp.50 RB BONUS PLAYCAFE Rp.15 RB       23
# PAKET GOPAY 50 RIBU                                    23
# Isi Ulang Zone Rp 30 s/d Rp 49                         23
# PAKET KARTU ZONE Rp.10.000 - Rp. 49.000                23
# PAKET KARTU ZONE Rp.150.000 - Rp. 249.000              23
# PAKET KARTU ZONE Rp.50.000 - Rp. 99.000                23
# NEW 150 BONUS 50%                                      23
# Isi Ulang Zone Rp 20 s/d Rp 29                         23
# Kartu Baru Zone Rp 30 s/d Rp 49                        23
# Isi Ulang Zone Rp 50 s/d Rp 99                         23
# PAKET KARTU 50rb + BONUS 100%                          22
# Isi Ulang 100Rb Bonus SOSRO                            22
# ISI ULANG 250RB BONUS 100%                             22
# PERDANA CARD 30-49RB                                   22
# PAKET GOPAY 100RB                                      22
# Kartu Baru Zone Rp 50 s/d Rp 99                        22
# Kartu Baru Zone Rp.50 Rb s/d Rp.99                     22
# kartu baru Zone Rp.100 Rb s/d Rp.499 Rb                22
# KARTU BARU Rp.50 RB BONUS 15RB + SOSRO                 22
# ISI ULANG PENDAMPING KE 2                              22
# KIDDIELAND BARU 1 JAM                                  22
# KIDDIELAND BARU SEPUASNYA                              22
# ISI ULANG 100rb-999 rb bonus 30%                       22
# Kartu Baru Zone Rp 100 s/d Rp 499                      22
# PAKET BUNDLING 50Rbu + CDEA + BONUS 15%                22
# ISI ULANG KIDDIEZONE 1 JAM WEEKEND                     22
# PAKET KARTU ZONE Rp.250.000 - Rp. 1.000.000            22
# ISI SALDO 10RB S/D 49RB                                22
# Pendamping ke2 dan seterusnya                          22
# Kartu Baru / Isi Ulang Zone Rp.50 K  s/d Rp.99 K       22
# KIDDIE WEEKEND 1 JAM                                   21
# KIDDIE WEEKEND SEPUASNYA                               21
# NEW ZONE Rp.100.000                                    21
# PAKET KARTU 50rb + 129%                                21
# Isi Ulang/Kb BRI 50K  Bonus 15K                        21
# SENIN-KAMIS SEPUASNYA KIDIELAND                        21
# PAKET BUNDLING 50K + TEH KOTAK + FRUITEA               21
# KIDDIEZONE WEEKEND 1 JAM + 1 KAOS KAKI.                21
# 100K BONUS 30%                                         21
# PAKET E ISI ULANG 50Rb                                 21
# ISI ULANG 150RB BONUS 70%                              21
# ISI ULANG  ZONE Rp.5 Rb s/d Rp.49 Rb                   21
# ISI ULANG KIDDIELAND WEEKDAY SEPUASNYA                 21
# NEW KIDDIEZONE 1 JAM WEEKDAY                           21
# NEW 50RB BONUS POPCRON                                 21
# SENIN-KAMIS KIDIELAND 1 JAM                            21
# PAKET E 50Rb                                           21
# PAKET DRp. 100rb                                       21
# PAKET C Rp.150RB                                       21
# Kartu Baru Zone 30rb s/d 99rb                          21
# Kartu Baru 100rb Non Tunai TTL Saldo 150rb             21
# PAKET BUNDLING 50K + SALMON BALL                       21
# KARTU BARU Rp.50 RB BONUS PLAYCAFE Rp.15 RB            21
# 50.000 BONUS SOSIS GORENG                              21
# Isi Ulang Rp. 10rb s/d 99rb                            21
# Kartu Baru Zone Rp.40 Rb                               21
# ISI ULANG PAKET D Rp. 100rb                            21
# ISI ULANG ZONE RP.30.000                               21
# PAKET KARTU 50Rbu TIKET.COM                            21
# PERDANA CARD 50-99RB BONUS 10%                         21
# PAKET KARTU SEPUASNYA WEEKDAY                          21
# PAKET KARTU BARU KIDDIELAND WEEKAND SP                 21
# PAKET KARTU ISI ULANG KIDDIELAND WEEKAND SP            21
# ISI ULANG 10RB S/D 25RB                                20
# New Zone Rp.30rb - Rp.49rb                             20
# PAKET BUNDLING 50Rbu + PRWAN BALL + BONUS 15%          20
# NEW ZONE Rp.50.000                                     20
# NEW ZONE Rp100.000 + PLAYCAFE                          20
# New Zone Rp. 100 rb - 149 rb BONUS 30%                 20
# Isi Ulang Zone Rp.100 rb - 149 rb BONUS 30%            20
# ISI ULANG KIDDIE LAND Rp 20.000                        20
# New Zone Rp.50000                                      20
# New Zone Rp. 50 rb-99 rb                               20
# PAKET BUNDLING 50K+FISH ROLL                           20
# Isi Ulang 100rb Non Tunai TTL Saldo 150rb              20
# Kartu Baru 150rb                                       20
# TOP UP ZONE 50 RB BANDLING POPCORN                     20
# 150k BONUS 50%                                         20
# ISI ULANG EDC BRI                                      20
# ISI ULANG KIDDIE ZONE SEPUASNYA WEEKEND                20
# PAKET 25 RIBU                                          20
# Kartu Baru Zone Rp.50 Rb s/d Rp.99 Rb 30%              20
# Kartu Baru Zone Rp.100 Rb s/d Rp.499 Rb 50%            20
# PAKET 30 RIBU                                          20
# PAKET Rp. 50.000                                       20
# Isi ulang Zone Rp.30 Rb S/d Rp.49 Rb                   20
# KARTU BARU KIDDIE LAND  Rp 20.000                      20
# KARTU BARU KIDDILAND WEEKEND 30 RB                     20
# Isi Ulang Zone Rp 30 rb s/d Rp 49 rb                   20
# KARTU BARU  Zone Rp.30rb - Rp.49Rb                     20
# Isi Ulang Zone Rp 30 rb - Rp 49 rb                     20
# Isi Ulang Zone Rp. 50 rb-99 rb                         20
# Zone Rp.30 Rb s/d Rp.49 Rb                             20
# KARTU BARU DAN ISI ULANG RP.150 RB- 499 RB             20
# ISI ULANG KIDDILAND WEEKEND 30 RB                      20
# Isi Ulang Zone Rp 50Rb                                 20
# Isi Ulang Zone Rp.2 Rb s/d Rp.29 Rb                    20
# PAKET 300 RB BONUS 100%                                20
# ISI ULANG ZONE Rp.100 Rb s/d Rp.499 Rb                 20
# KIDDIEZONE WEEKDAY 1 JAM + 1 KAOS KAKI                 20
# KIDDIEZONE WEEKDAY SEPUASNYA + 1 KAOS KAKI             20
# New Zone 65rb-99rb                                     20
# ISI ULANG 30 RB/ 49 RB                                 20
# ISI ULANG ZONE Rp.100 Rb s/d Rp.149 Rb                 20
# KARTU BARU KIDIELAND 25.000                            20
# PEMBELIAN SALDO 50 GRATIS POPCORN                      20
# KARTU BARU 50rb                                        20
# KARTU BARU 100 rb                                      20
# Zone Rp.20 Rb s/d Rp.29 Rb                             20
# Kartu Baru  Zone Rp.100 Rb s/d Rp.499 Rb               20
# ISI ULANG KIDDELAND 25.000                             20
# KIDDIEZONE WEEKEND SEPUASNYA + 1 KAOS KAKI.            20
# 100rb bonus 100%                                       20
# MEGA SALE JSM (12/13.16/17.19/20)                      20
# PAKET KIDDIELAND WEEKEND 2JAM                          20
# 50.000 BONUS DUMPLING                                  20
# NEW ZONE Rp50.000 + PLAY CAFE                          20
# ISI ULANG 10rb - 49rb                                  20
# ISI ULANG 30RB - 45RB                                  20
# Kartu Baru 70rb Non Tunai TTL Saldo 90rb               20
# KARTU BARU ZONE Rp 30 rb s/d Rp 49 rb                  20
# KARTU BARU KZ SEPUASNYA                                20
# Isi Ulang 150rb                                        20
# IZI ULANG KZ SEPUASNYA                                 20
# KIDDIE LAND  SEPUASNYA WEEKAND                         20
# KARTU BARU EDC BRI                                     20
# PAKET BUNDLING 50Rbu + FISH ROLL + BONUS 15%           20
# 50.000 BONUS POP MIE                                   20
# KARTU BARU ZONE Rp 50 rb s/d Rp 99 rb                  20
# ISI ULANG KARTU 10 K S/D 50 K                          20
# ISI KIDDIELAND 1 JAM                                   20
# KARTU BARU 30 RB - 49 RB                               19
# Top Up Paper Rp.20.000 s/d Rp.49.000                   19
# PAKET BUNDLING 100Rbu + KENTANG + BONUS 80%            19
# New Zone Rp.30Rb - Rp.49Rb                             19
# PERDANA 150K BONUS 50 %                                19
# PAKET BUNDLING 50K + BAKSO G.                          19
# Isi Ulang Rp.10000 - 29000                             19
# ISI ULANG 50RB BONUS 10%                               19
# Isi Ulang Zone Rp 100 Rb                               19
# NEW KIDDIE LAND WEEKDAY 1JAM                           19
# KIDDIE ZONE 1 JAM WEEKEND                              19
# PAKET 200K DST BONUS 100%                              19
# New Zone Rp.50 Rb                                      19
# Kartu Baru 200rb Non Tunai TTL Saldo 320rb             13
# ISI ULANG KIDDIE LAND 1 JAM RP 35000                   13
# RECHARGE LIMITED CARD 100 -500                         13
# KIDDIE LAND KARTU BARU 1 JAM RP. 35000                 13
# TOP UP 200k (2 Produk Playcafe)                        13
# NEW/ISI ULANG 100K + 30%                               13
# NEW ZONE Rp. 250.000 s/d Rp.999.999BONUS 100%          13
# ISI ULANG KARTU 300K MEGA SALE 150%                    13
# NEW KIDDIELAND WEEKDAY 1 JAM                           13
# MEGA SALE 250 K BONUS 150%                             13
# PAKET 100 Ribu BONUS MINERAL                           13
# 200K BUNDLING FNB 18K                                  13
# PERDANA Rp 30000 s/d Rp 49000                          13
# ISI ULANG KARTU 100K + BONUS 50%                       13
# PAKET 50K (TBK)                                        13
# PAKET BUNGLING 100Rbu + LOBSTER BALL + BONUS 80%       13
# KARTU PROMO FAMILY DAY 10K                             13
# KIDDIE ZONE WEEKEND SEPUASNYA + KK ANAK                13
# MEGA SALE 150%                                         13
# KARTU BARU 75K +  50%                                  13
# KARTU BARU Rp.30rb - Rp.49rb                           13
# ISI ULANG 75K BONUS 100%                               13
# PAKET BUNDLING 100Rbu + POP MIE + BONUS 80%            13
# Kartu Baru KL 2                                        13
# PAKET KARTU ISI ULANG KIDDIELAND WEEKEND JAM           13
# isi Ulang KIDS LAND Weekend                            13
# ISI ULANG 50K BONUS 10%                                13
# ISI ULANG KIDDIE WORLD WEEKDAY 1JAM                    13
# Isi Ulang KL WEEKDAY SEPUASNYA + KAOS KAKI 55K         13
# PROMO SOSRO Rp.30 Rb FREE 1 PCS SOSRO 200 ML           13
# PAKET GOPAY 200RB                                      13
# Paket Kartu 50 K Bonus Pop Corn                        13
# Paket Kartu 50 K Bonus Ice Cream                       13
# TOP UP 50RB Free (1 Produk Playcafe)                   13
# NEW CARD TRANSAKSI 250RB - 500RB BONUS SALDO 100%      13
# ISI ULANG TRANSAKSI 250RB - 500RB BONUS SALDO 100%     13
# PAKET KARTU 50rb + BONUS 100% + 2 PRIMA                13
# NEW 50RB Free (1 Produk Playcafe)                      13
# Isi Ulang 150rb Non Tunai TTL Saldo 220rb              12
# Promo Kartu Rp. 150rb bonus Playcafe NEW               12
# PAKET KIDDIE LAND WEEKEND ( 2 ANAK )                   12
# PAKET KIDDIE LAND WEEKEND ( 3 ANAK )                   12
# paket 250rb bonus 100%                                 12
# 50rb bonus 10%+Teh kotak                               12
# PEMBELIAN 200RB BONUS 75%                              12
# TOP UP KIDDIE LAND SEPUASNYA                           12
# Isi Ulang Zone Rp.50 Rb s/d Rp.99 Rb Bonus 0%          12
# kartu baru kl weekday sepuasnya ++ kaos kaki 60k       12
# PAKET TIKET.COM 200Rb                                  12
# KIDDIE LAND WEEKEND ( 1 JAM ) Rp.35.000                12
# Isi Ulang Zone Rp.30 Rb s/d Rp.49 Rb Bonus 10%         12
# PAKET TIKET.COM 100Rb                                  12
# NEW KARTU 300K MEGA SALLE 150%                         12
# Isi Ulang Zone Rp.15 Rb s/d Rp.49 Rb                   12
# KARTU BARU Paket D Tiket.com Rp. 100 Rb                12
# PAKET 150K                                             12
# KIDDIE WEEKDAY SEPUASNYA                               12
# KIDDIE  WEEKDAY 1 JAM                                  12
# ISI ULANG KARTU 100K + BONUS 30%                       12
# PAKET BUNDLING 50K + DUMPLING AYAM                     12
# ISI ULANG 250 K BONUS 100%                             12
# PERDANA 50K BONUS 10%                                  12
# ISI ULANG 100K+ POP CORN +30%                          12
# PAKET KARTU 50K BONUS POP CORN + 10%                   12
# Top Up 100k Nontunai                                   12
# Top Up 50k Nontunai                                    12
# KDL BARU 20K                                           12
# New 100k Nontunai                                      12
# ISI ULANG KIDDIE WEEKEND SEPUASNYA                     12
# KARTU KIDDIELAND WEEKEND SEPUASNYA                     12
# 50RB BANDLING DUMPLING KEJU                            12
# 50K BONUS DUMPLING AYAM                                12
# PAKET 50rb + 2PRODUK SOSRO(FRUITEA)                    12
# PAKET 100+ 2 TBK+65POINT                               12
# Rp.50.000,- DAPAT 1 TUSUK BAKSO UDANG+10%              12
# Rp.50.000,- DAPAT 1 TUSUK SALMON BALL + 10%            12
# Beli 50K Dapat Makaroni                                12
# Beli 50k Dapat Chiken Nugget                           12
# KIDDIE BARU WEEKDAY SEPUASNYA                          12
# KIDDIELAND BARU WEEKDAY 1 JAM                          12
# Kartu Baru / Isi Ulang Zone Rp.100 K  s/d Rp.249K      12
# KIDDIE LAND SEJAM WEEKEND                              12
# KIDDIE LAND SEJAM WEEKDAY                              12
# New 100Rb Bonus SOSRO                                  12
# ISI ULANG PROMO 250K BONUS 100%                        12
# KARTU BARU 50K FREE POPCORN                            12
# Kiddie Zone Weekday 1 Jam Rp.30 Rb                     12
# Kiddie Zone Weekend Sepuasnya Rp.45 Rb                 12
# Kiddie Zone Weekend 1 Jam Rp.35 Rb                     12
# Kiddie Zone Weekday Sepuasnya Rp.40 Rb                 12
# MOBIL LAMPU INDOOR 10 MENIT RP. 20.000                 12
# New Zone Rp.100rb Non Tunai                            12
# ISI KIDI ZONE WEEKEND 1 JAM                            12
# NEW ISI ULANG 150.000 + POP CORN + 2 PRODUK SOSRO      12
# KIDDIELAND 1 JAM 40K weekend                           12
# TIKET.COM 100K                                         12
# New Zone Rp. 50rb Non Tunai                            12
# Isi Ulang Zone Rp. 50rb Non Tunai                      12
# KARTU BARU 15rb - 29rb                                 12
# Isi Ulang Zone Rp. 100rb Non Tunai                     12
# Isi Ulang Zone Rp. 150rb Non Tunai                     12
# PLAY A BONUS 10 POINT                                  12
# NEW ZONE 65RB + FOTO BOOTH                             11
# PAKET TIKET.COM 200K                                   11
# PAKET 50 RIBU BONUS POP CORN                           11
# ISI ULANG ZONE Rp.100 Rb Rb s/d Rp.499 Rb              11
# PAKET TIKET.COM 100K                                   11
# PAKET KARTU LOMBA 25K                                  11
# PAKET PENDAMPING CHOCHO TRAIN 7K                       11
# ISI ULANG 100K BONUS 30%                               11
# New Zone Rp.50 Rb s/d Rp.90 Rb 15%                     11
# MOBIL LAMPU                                            11
# New Zone Rp.100 Rb bonus50 %                           11
# KARTU BARU ZONE 50k Prima                              11
# KARTU BARU ZONE 50K                                    11
# KARTU BARU ZONE 100K                                   11
# ISI ULANG ZONE Rp.20 Rb s/d Rp.49 Rb                   11
# ISI ULANG ZONE 50K                                     11
# PAKET KARTU BARU KIDDIE ZONE WEEKDAY SEPUASNYA         11
# MEGASALE BONUS 100 RIBU                                11
# New Zone Rp 30RB s/d 40 RB                             11
# New Kidie Rp.30 Rb s/d Rp.49 Rb.                       11
# Paket Tiket.com 100K                                   11
# ISI LANG KARTU 50RB S/D 99RB                           11
# ISI ULANG ZONE 200K BONUS 200 POIN                     11
# NEW KIDDIE WEEKDAY SEPUASNYA Rp 30rb                   11
# ISI ULANG KIDDIE WEEKDAY SEPUASNYA Rp 30rb             11
# ISI ULANG KIDDIE WEEKEND Rp 35rb Sepuasnya             11
# PLAY 150K BUNDLING FNB 18K BONUS 70%                   11
# Isi Ulang Zone Rp.50 Rb s/d Rp.90 Rb 15%               11
# 30K BONUS 10%                                          11
# PLAY 100K BUNDLING 9K BONUS 70%                        11
# Isi Ulang Zone Rp.10RB S/D 40RB                        11
# ZOOMOVE 15K                                            11
# PAKET KIDDIELAND SEPUASNYA                             11
# KIDDIELAND SEPUASNYA 50K Weekend                       11
# PERDANA CARD 100K + BONUS 30%                          11
# PAKET BUNDLING 50K+KENTANG GORENG                      11
# ISI ULANG ZONE RP.50.000                               11
# ISI ULANG DEBIT CARD BCA 100K + 30% T. POIN 154        11
# KL Week Day Sepuasnya Rp 40.000                        11
# 50K BONUS ICE CREAM CUP                                11
# 100K BANDLING KENTANG GORENG + SALDO 70%               11
# KARTU BARU PROMO 200% MEGA SALE                        11
# ISI ULANG ZONE 100K  BONUS 30%                         11
# Kartu Baru KIDS LAND Weekend                           11
# KIDDIE ZONE SEPUASNYA WEEKDAY                          11
# Beli 50K Dapat Kacang Telur                            11
# Beli 50K Dapat Kacang Koro                             11
# Rp.50.000,- DAPAT 1 TUSUK DUMPLING AYAM +10%           11
# ISI ULANG 50 RB BONUS 10%                              11
# NEW ISI ULANG 100.000 + BONUS SALD0 30%                11
# NEW ISI ULANG 150.000 ( BONUS SALDO 50% )              11
# PAKET KARTU 20rb QPON                                  11
# Isi Ulang Zone Rp.100 Rb s/d Rp.499 Rb BONUS 50%       11
# Isi Ulang Zone Rp.50 Rb s/d Rp.99 Rb BONUS 30 %        11
# New Zone Rp.100Rb s/d Rp.499Rb BONUS 50%               11
# New Zone Rp.50 Rb s/d Rp.99 Rb BONUS 30 %              11
# New KIDDIE WEEKEND Rp 35 rb Sepuasnya                  11
# ISI ULANG 100K BONUS 30                                11
# KARTU BARU 250 RB BONUS 100%                           11
# ISI ULANG 250 RB BONUS 100%                            11
# ISI ULANG DEBIT BCA 150K T. POIN 300                   11
# KIDDIE LAND                                            11
# New Zone Rp.50 Rb bonus 10%                            11
# New Zone Rp.100 Rb bonus 30 %                          11
# Pkt Prima Rp.50 Rb Ttl 78 Poin                         11
# Kartu Baru / Isi Ulang Zone Rp.250 K  s/d Rp.500 K     11
# ISI ULANG KIDDIE WEEKDAY SEPUASNYA                     11
# 30.000 BONUS PRIMA                                     11
# NEW ZONE Rp 65.000 KERAMAS + PRIMA                     11
# New 150k Nontunai                                      11
# Kartu Baru / Isi Ulang 100 k Bonus Kentang             11
# Kartu Baru / Isi Ulang 100 k Bonus C Nugget            11
# Kiddie Zone 1Jam Rp.45.000 Weekday+Kaos Kaki           11
# Kiddie Zone Sepuasnya Rp.60.000 Weekend+Kaos Kaki      11
# NEW 150k (2 Produk Playcafe)                           11
# TOP UP 150k (2 Produk Playcafe)                        11
# ISI ULANG KIDDIE WORLD WEEKDAY SPUASNYA                11
# TIKET.COM Rp. 100.000                                  11
# PAKET BUNDLING 50K+DUMPLING KEJU                       11
# ISI ULANG ZONE 100K                                    11
# ZOOMMOVE WEEKAND  Rp.15000                             11
# New Zone Rp.100 Rb s/d Rp.499 Rb Bonus 100%            11
# New Zone Rp.50 Rb s/d Rp.99 Rb Bonus 0%                11
# PAKET KIDDIE LAND WEEKEND                              11
# PAKET KIDDIE LAND WEEKDAY                              11
# NEW /ISI ULANG 50K + 10%                               11
# NEW 150K + 50%                                         11
# New Zone Rp.100rb s/d 999rb 30%                        11
# KARTU BARU 50RB Bonus 22 Poin                          11
# ISI ULANG ZONE RP.30.000 BONUS 3000                    11
# PAKET BUNDLING 100K + FRUITEA + TEH KOTAK              11
# 50rb bonus fnb popcorn 2 (12rb)                        11
# Rp. 50.000 (Jml Poin 80) + 1 MINUMAN                   11
# Isi Ulang Zone Rp.100 rb bonus 30%                     10
# PAKET HARGA Rp.100 GRATIS TEH SOSRO                    10
# ISI ULANG 100 K + 70%                                  10
# Isi Ulang Zone Rp.50 Rb + 10%                          10
# Isi Ulang Zone Rp.10RB S/D 49 RB                       10
# PAKET KARTU BARU KIDDIE ZONE  SEPUASNYA                10
# NEW ZONE 200K BONUS 200 POIN                           10
# NEW KIDDIE WEEKDAY Rp 25rb 1 JAM                       10
# 100K BUNDLING FNB+WAHANA BONUS 70%                     10
# KIDDIELAND 1 JAM 35K WEEKDAY                           10
# KIDDIELAND SEPUASNYA 40K WEEKDAY                       10
# ISI ULANG KARTU 100K BONUS 30%                         10
# Isi Ulang Kidie Rp.50 Rb s/d Rp.99 Rb BONUS 15 %       10
# NEW KIDIE ZONE WEEKEND RP. 50.000 SEPUASNYA            10
# NEW KIDIE ZONE WEEKEND RP. 40.000 1 JAM                10
# New Kiidie Rp. 150 Rb BONUS 50 %                       10
# SILANG KIDIE ZONE WEEKDAY RP. 35.000 1 JAM             10
# SILANG KIDIE ZONE WEEKEND RP. 40.000 1 JAM             10
# PLAY 50K BUNDLING FNB 9K BONUS 15%                     10
# PERDANA CARD 100K + BONUS 50%                          10
# KARTU BARU 250 K BONUS 100%                            10
# PROMO DANA 100K                                        10
# SILANG KIDIE ZONE WEEKEND RP. 50.000 SEPUASNYA         10
# Isi Ulang Kartu Rp.100 Rb s/d Rp.490 Rb Bonus 70%      10
# Promo Kartu Baru Rp.50 Rb s/d Rp.99 Rb Bonus 30%       10
# ISI ULANG KIDDIE LAND                                  10
# PROMO DANA 50K                                         10
# ISI ULANG 50K + 15%                                    10
# KL Week End Sepuasnya Rp 45.500                        10
# 50K DAPAT 1 PORSI SOSIS GORENG                         10
# BELI 50K BONUS CHIKI RING                              10
# Rp.50.000,- DAPAT 1 TUSUK FISH ROLL +10%               10
# Beli 50K Dapat Keripik Singkong                        10
# PAKET KARTU 50K BUNDLING FRUITTEA                      10
# PERDANA 100K BONUS 30                                  10
# MEGA SALE               KARTU      ISI ULANG           10
# 50RB BANDLING COCA-COLA                                10
# 50K BONUS FISHROLL                                     10
# ISI  ULANG KARTU 30K + ICE CREAM                       10
# KL ISI ULANG/KB WEEK DAY 1 Jam W/ BRI Rp 30K           10
# KIDDIE ZONE WEEKDAY 1 JAM + KK ANAK                    10
# PAKET KIDDIE LAND WEEKDAY ( 2 ANAK )                   10
# ISI ULANG 250 BONUS 100%                               10
# kartu baru kl weekend satu jam ++ kaos kaki 60k        10
# PAKET KARTU 200RB BONUS 100%                           10
# ISI ULANG 50RB BONUS 22 Poin                           10
# 50RB BANDLING SPRITE                                   10
# 100K BANDLING CHICKEN NUGGET                           10
# PAKET QPON 50K                                         10
# 100k Gratis Nugget BONUS 30%                           10
# PAKET 100K BONUS 30% + POPCORN                         10
# PROMO SOSRO Rp.30 Rb FREE 1 PCS PRIMA 600 ML           10
# IS SALDO Rp.150 RB BONUS 50%                           10
# KIDDIE LAND WEEKEND ( 1 JAM ) Rp.35000                 10
# Isi Ulang Zone Rp.100 Rb s/d Rp.499 Rb BONUS 100%      10
# ISI ULANG  ZONE 50 RB BANDLING KENTANG GORENG          10
# NEW/ISI SEPUASNYA KIDIELAND WEEKEND Rp.45 rb           10
# ISI ULANG KIDDIE ZONE WEEKND SEPUASNYA Rp.50.000,-     10
# III MEGA SALE 200%                                     10
# PAKET KARTU 50K BUNDLING POPCORN                       10
# ISI ULANG Rp. 200.000 s/d Rp. 999999 BONUS 100%        10
# New Zone Rp. 150rb Non Tunai                           10
# KARTU BARU ZONE 100K BONUS 30%                         10
# PAKET KARTU BARU KIDDIELAND WEEKDAY 1 JAM              10
# KARTU BARU ZONE 50K BONUS 10%                          10
# Isi Ulang KL 2 SP                                      10
# 100RB BONUS 100%+ BATRE CAR                            10
# KIDDIEZONE1 JAM 35.000 WEEKEND                         10
# KIDDIEZONE WEEKDAY 30RB/1 JAM                          10
# KIDDIEZONE 45.500 SEPUASNYA WEEKEND                    10
# 50rb bonus fnb popcorn 1 (12rb)                        10
# PAKET KARTU BARU KIDDIELAND WEEKDAY SP                 10
# PAKET KARTU ISI ULANG KIDDIELAND WEEKDAY SP            10
# ISI ULANG 50K + 10%                                    10
# Isi Ulang KL2   1JAM                                   10
# Zone Rp.100 Rb s/d Rp.499 Rb Bns 42 Poin               10
# PAKET ISI ULANG KIDDIELAND WEEKDAY 1JAM                10
# Pkt Fanta Rp.50 Rb Ttl 78 Poin                         10
# Zone Rp.50 Rb s/d Rp.99 Rb Bns 7 Poin                  10
# ISI ULANG ZONE 50K  BONUS 10%                          10
# Isi Ulang Zone Rp.10 K  s/d Rp 49 K                    10
# ...
# PAKET 100.000 TIKET.COM                                 1
# PAKET KARTU 200RB TIKET.COM                             1
# PAKET KARTU100K BUNDLING FRUITEA+PRIMA                  1
# ISI ULANG KIDDIELAND PROMO                              1
# Isi Ulang Zone 100Rb + 2 POPCONR                        1
# Isi Ulang Zone 50Rb + 2 POPCORN                         1
# NEW KIDDIELAND PROMO                                    1
# New Zone 100Rb + 2 POPCORN                              1
# New Zone 50Rb + 2 POPCORN                               1
# Isi Ulang Zone 50Rb + POPCORNN                          1
# New Zone 100Rb + CHIKEN NUGGET                          1
# Isi Ulang Zone 100Rb Bonus 70%                          1
# ISI ULANG 100K 30% + 1 NUGGET + TBK                     1
# ISI ULANG 100K 30% + C NUGGET + TBK                     1
# ISI ULANG 100K 30% + 1 CHICKEN WINGS + TBK              1
# ISI ULANG 100K 30% + 1 CHIKEN NUGGET + TBK              1
# KARTU BARU 50K BONUS 50% + FRUITTEA                     1
# KARTU BARU 50K BONUS 50% + PRIMA                        1
# KARTU BARU 50K BONUS 50% + PRIMA + KUPON SUKA SUKA      1
# PROMO PAKET 150K + 70%                                  1
# PROMO LOKAL 30 RB BUNDLING TEH KOTAK                    1
# PAKET 100 K  BUNDLING FRUITEA + SALMON B.               1
# PAKET 100 K  BUNDLING TEH KOTAK + SALMON B.             1
# PEMBELIAN MESIN  50 K                                   1
# PEMBELIAN 50K BONUS SOSRO  + SALDO 10%                  1
# Isi ulang Kiddie Rp.30 Rb s/d Rp 49 Rb                  1
# KIDDIELAND SENIN S/D KAMIS Rp. 45,000                   1
# ISI ULANG 100K BUNDLING SPRITE                          1
# ISI ULANG KARTU 50K BUNDLING BAKSO GORENG               1
# ISI ULANG KARTU 50K BUNDLING CHIKEN NUGGET              1
# ISI ULANG KARTU 50K BUNDLING POPCORN                    1
# ISI ULANG KARTU 50K BUNDLING SPRITE                     1
# PAKET KARTU100K BUNDLING BAKSO GORENG                   1
# PAKET KARTU100K BUNDLING CHIKEN WINGS                   1
# TIKET.COM PAKET 100RB                                   1
# 50%NEW COMBO 1 100K 2 COLA                              1
# 50%NEW COMBO 1 100K 2 FANTA                             1
# 50%NEW COMBO 1 100K 2 SOSIS                             1
# 50%NEW COMBO 1 100K 2 TBK                               1
# 50%NEW COMBO 1 100K+ 1 COLA+ 1 POP12                    1
# 50%NEW COMBO 1 100K+ 1 FANTA + 1 POP12                  1
# ISI ULANG 100K 50%+ 1 CHICKEN NUGGET + 1 PC 12K         1
# ISI ULANG 100K 50%+ 1 KENTANG                           1
# ISI ULANG 100K 50%+ 1 NUGGET                            1
# NEW KARTU ZONE 100K 50% + 2 PLAY CUT+50%                1
# NEW KIDDIE WORLD WEEKDAY SPUASNYA                       1
# ISI ULANG 100K BUNDLING FRUITEA+PRIMA                   1
# ISI ULANG 100K BUNDLING FRUITTEA+PRIMA                  1
# ISI ULANG 100K BUNDLING FRUITTEA+TBK                    1
# KURSI PIJAT 15 K                                        1
# PEMBELIAN MESIN  20 K                                   1
# ISI ULANG 100K BUNDLING CHIKEN WINGS                    1
# ISI ULANG PAKET 100K BUNDLING SPRITE + FANTA            1
# ISI ULANG PAKET KARTU 30K BUNDLING TBK                  1
# ISI ULANG PAKET KARTU 50K BUNDLING BAKSO GORENG         1
# PAKET KARTU 100K BUNDLING COCACOLA + FANTA              1
# PAKET KARTU 100K BUNDLING SPRITE + FANTA                1
# PAKET 100K + 50%+ FRUIT TEA                             1
# PAKET A TIKET.COM RP.30 RB                              1
# PAKET KARTU 30rb + BONUS 15% + 1 COCA COLA              1
# PAKET 100K + 50%  + PRIMA 2 pcs                         1
# New Rp.100.000 Bonus 70%+Voucher P.Cafe+T.Sosro         1
# New Rp.250.000 Bonus 100%                               1
# New Rp.50.000 Bonus 80%+Fruit Tea 200 Ml                1
# Top Up Rp. 100.000 Bonus 80%+ Teh Sosro 200Ml           1
# Top Up Rp.50.000 Bonus 80%+Fruit Tea 200 Ml             1
# ISI ILANG 250K + 100% POINT T. POINT 714                1
# ISI ULANG  KIDDIE ZONE SEASON LEBARAN 50K               1
# NEW 30K + KUPON ARISAN SALDO                            1
# NEW 50K BNUS 15% + SPRITE                               1
# KIDDIEZONE SEPUASNYA 38.500 WEEKDAY                     1
# NEW 50K + 15% + POPCORN                                 1
# ISI ULANG 100K + DUMPLING CHICKEN + TBK T.POIN 242      1
# ISI ULANG 50K + 15% +TBK                                1
# PAKET 100RB FREE GIFT                                   1
# PAKET BUNDLING 50Rbu + CHICKEN WINGS + BONUS 15%        1
# SALDO 100 BONUS 100%                                    1
# PAKET 10rb + BONUS 50%                                  1
# PAKET KARTU 100 rb+ BONUS + 1 SOSRO + 1 MINERAL         1
# PAKET KARTU 50rb + BONUS 30% + 1 SOSRO + 1 MINERAL      1
# PAKET KARTU 100K Sosro 4pcs                             1
# KIDDIE LAND 50% WEEKDAY                                 1
# Name: count, dtype: int64

# %% [markdown]
# Fungsi Mapping

# %% [markdown]
# Kode ini mencakup:
#
# * Ekstraksi Nominal: Mendeteksi angka (20rb, 50k, 100.000, dst).
#
# * Kategorisasi Tipe: Memisahkan antara "Kiddie Land", "Bundling F&B", dan "Regular".
#
# * Penggabungan: Membuat kolom akhir yang rapi.

# %%
# ================= 1. FUNGSI EKSTRAK NOMINAL (FINAL V4) =================
def ekstrak_nominal_final(teks):
    """
    Mendeteksi nominal uang dengan logika:
    1. Hapus persen (%).
    2. Cek Konteks (NEW/ZONE/HARGA) dengan batas kata (\b) agar KIDDIEZONE aman.
    3. Cek 'k'/'rb'.
    4. Cek Format Rupiah Standar.
    5. Ambil yang paling depan (First Match).
    """
    t_raw = str(teks).lower()
    
    # 1. Bersihkan angka persen (misal 100%)
    t = re.sub(r'\d+\s*%', '', t_raw)
    
    found_candidates = [] 

    # 2. Pola Kontekstual (NEW 65, ZONE 100)
    # Pakai \b agar 'KIDDIEZONE' tidak dianggap 'ZONE'
    pola_context = re.finditer(r'\b(?:new|zone|harga|isi ulang)\s*(?:rp\.?)?\s*(\d{2,3})\b', t)
    for match in pola_context:
        angka = int(match.group(1))
        if 10 <= angka <= 999: # Filter angka masuk akal
            found_candidates.append((match.start(), angka * 1000))

    # 3. Pola 'k' / 'rb' (50k, 100rb)
    pola_k = re.finditer(r'(\d+)\s*(k|rb|ribu)', t)
    for match in pola_k:
        found_candidates.append((match.start(), int(match.group(1)) * 1000))

    # 4. Pola Rupiah Lengkap (150.000, 500000)
    pola_angka = re.finditer(r'(?:rp\.?)?\s*(\d{1,3}(?:\.\d{3})+|\d{4,})', t)
    for match in pola_angka:
        val = int(match.group(1).replace('.', '').replace(',', ''))
        if val >= 5000: # Filter angka qty/tahun
            found_candidates.append((match.start(), val))

    # 5. Ambil Kandidat Paling Depan
    if not found_candidates:
        return 'Lainnya'
    
    found_candidates.sort(key=lambda x: x[0])
    nilai_final = found_candidates[0][1]
    
    # Formatting
    if nilai_final >= 1000000: return f"{int(nilai_final/1000)}k" 
    elif nilai_final >= 1000: return f"{int(nilai_final/1000)}k"
    else: return str(nilai_final)

# ================= 2. FUNGSI CEK TIPE (FINAL PRIORITY) =================
def cek_tipe_paket_final(teks):
    t = str(teks).lower()
    
    # Prioritas 1: KARTU PERDANA
    keyword_perdana = ['perdana', 'kartu baru', 'new card', 'starter']
    if any(k in t for k in keyword_perdana): return 'Kartu Perdana'

    # Prioritas 2: KIDDIE LAND (Termasuk KIDDIEZONE)
    if 'kiddie' in t or 'kiddy' in t or re.search(r'\bkl\b', t): return 'Kiddie Land'
    
    # Prioritas 3: BUNDLING F&B
    keyword_fnb = [
        'bundling', 'fruitea', 'fruit tea', 'kentang', 'ayam', 'kupon', 'tbk',
        'sosro', 'teh', 'fanta', 'sprite', 'cola', 'minum', 'drink', 'bottle',
        'popcorn', 'pop corn', 'corn', 'ice', 'krim', 'cream', 'cone', 'milo',
        'nugget', 'sosis', 'bakso', 'fish', 'roll', 'ball', 'wings', 
        'dumpling', 'odeng', 'bento', 'milky', 'snack', 'platter',
        'minyak', 'gula', 'chiki', 'oreo', 'biskitop', 'kusuka', 'yupi',
        'balon', 'kaos kaki', 'fnb', 'meal', 'makan', 'nyemil', 'biskuit',
        'pakan', 'boneka', 'merchandise', 'hampers', 'hadiah', 'box',
        'mineral', 'capucino', 'prima', 'goreng', 'kepang'
    ]
    if any(k in t for k in keyword_fnb): return 'Bundling F&B/Barang'
    
    # Prioritas 4: BUNDLING WAHANA
    keyword_wahana = [
        'driving', 'school', 'bumper', 'car', 'atv', 'golf', 'soccer', 'padel',
        'bouncer', 'human', 'claw', 'blowing', 'photobox', 'photo', 'booth',
        'karaoke', 'makeup', 'face', 'painting', 'pijat', 'massage', 'snow',
        'train', 'chocho', 'robot', 'zoomove', 'walking', 'game', 'play', 'kursi pijat'
    ]
    if any(k in t for k in keyword_wahana): return 'Bundling Wahana'

    # Prioritas 5: BONUS
    if 'bonus' in t or ' bns ' in t or 'free' in t: return 'Regular Top Up dengan Bonus'

    return 'Regular Top Up'

# ================= 3. FUNGSI GROUPING FINAL =================
def final_grup_logic(row):
    if row['Tipe_Grup'] == 'Kiddie Land':
        return 'Kiddie Land'
    elif row['Nominal_Grup'] == 'Lainnya':
        return row['Tipe_Grup']
    else:
        return f"{row['Nominal_Grup']} - {row['Tipe_Grup']}"

# ================= 4. EKSEKUSI UTAMA (TERAPKAN KE DF_CLEAN) =================

print("🚀 Memulai Proses Mapping Lengkap...")

# A. Apply Nominal & Tipe
df_clean['Nominal_Grup'] = df_clean['Paket'].apply(ekstrak_nominal_final)
df_clean['Tipe_Grup'] = df_clean['Paket'].apply(cek_tipe_paket_final)

# B. OVERRIDE: Paksa Nominal jadi 'Lainnya' jika tipe Kiddie Land
# (Agar 100k di KiddieZone tidak terbaca sebagai uang topup)
df_clean.loc[df_clean['Tipe_Grup'] == 'Kiddie Land', 'Nominal_Grup'] = 'Lainnya'

# C. Apply Kategori Final
df_clean['Kategori_Paket'] = df_clean.apply(final_grup_logic, axis=1)

print("✅ PROSES SELESAI! Mapping sudah diperbarui.")

# ================= 5. CEK HASIL ACAK =================
print("\n🔍 Contoh Hasil Mapping:")
cols = ['Paket', 'Nominal_Grup', 'Tipe_Grup', 'Kategori_Paket']
# Ambil contoh acak + contoh spesifik
contoh_spesifik = df_clean[df_clean['Paket'].str.contains('KIDDIE|ZONE 100|NEW 65', case=False, na=False)].head(5)
contoh_acak = df_clean.sample(5)

display(pd.concat([contoh_spesifik, contoh_acak])[cols])
# Out:
# 🚀 Memulai Proses Mapping Lengkap...
# ✅ PROSES SELESAI! Mapping sudah diperbarui.
#
# 🔍 Contoh Hasil Mapping:
#                                           Paket Nominal_Grup  \
# 0         FINTECH KIDDIE ZONE WEEKEND SEPUASNYA      Lainnya
# 1               KIDDIE ZONE WEEKDAY 1 JAM + KKP      Lainnya
# 2           KIDDIE ZONE WEEKDAY SEPUASNYA + KKP      Lainnya
# 3           KIDDIE ZONE WEEKEND 1 JAM + KK ANAK      Lainnya
# 4       KIDDIE ZONE WEEKEND SEPUASNYA + KK ANAK      Lainnya
# 12290           PAKET 50 RIBU BONUS TBK + PRIMA          50k
# 8836           NEW KIDDIELAND WEEKEND SEPUASNYA      Lainnya
# 12359           PEMBELIAN 50 RIBU BONUS POPCRON          50k
# 26851                       ISI ULANG Rp.10.000          10k
# 22601  PAKET BUNDLING 50Rbu + NUGET + BONUS 15%          50k
#
#                          Tipe_Grup                     Kategori_Paket
# 0                      Kiddie Land                        Kiddie Land
# 1                      Kiddie Land                        Kiddie Land
# 2                      Kiddie Land                        Kiddie Land
# 3                      Kiddie Land                        Kiddie Land
# 4                      Kiddie Land                        Kiddie Land
# 12290          Bundling F&B/Barang          50k - Bundling F&B/Barang
# 8836                   Kiddie Land                        Kiddie Land
# 12359  Regular Top Up dengan Bonus  50k - Regular Top Up dengan Bonus
# 26851               Regular Top Up               10k - Regular Top Up
# 22601          Bundling F&B/Barang          50k - Bundling F&B/Barang

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# Persiapan & Konfigurasi Visualisasi

# %%
# Setting Tampilan
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Fungsi Formatter Rupiah (Juta/Miliar) untuk Sumbu Grafik
def format_rupiah_axis(x, pos):
    if x >= 1e9:
        return f'Rp {x*1e-9:.1f} M'
    elif x >= 1e6:
        return f'Rp {x*1e-6:.0f} Jt'
    else:
        return f'Rp {x:,.0f}'

formatter = ticker.FuncFormatter(format_rupiah_axis)

# %% [markdown]
# **Business Questions**

# %% [markdown]
# **1. Toko mana saja yang memiliki performa tertinggi dan terendah dalam dua tahun terakhir?**

# %%
# Fungsi Helper untuk Label Angka (Agar Rapi) ---
def format_label_rupiah(x):
    if x >= 1e9:
        return f'Rp {x/1e9:.1f} M'  # Miliar
    elif x >= 1e6:
        return f'Rp {x/1e6:.0f} Jt' # Juta
    else:
        return f'Rp {x:,.0f}'

# Persiapan Data ---
# Rename Kolom untuk Visualisasi
store_perf = df_clean.groupby('Folder_Asal')['Omset_Paket'].sum().sort_values(ascending=False).reset_index()
store_perf = store_perf.rename(columns={'Folder_Asal': 'Nama Toko'})

# Plotting ---
fig, axes = plt.subplots(2, 1, figsize=(14, 14)) # Tinggi figure sedikit ditambah agar lega

# GRAFIK 1: TOP 10 ===
sns.barplot(
    data=store_perf.head(10), 
    x='Omset_Paket', 
    y='Nama Toko', 
    palette='Blues_r', 
    ax=axes[0]
)
axes[0].set_title('🏆 Top 10 Toko dengan Performa Tertinggi (Omset)', fontsize=14, fontweight='bold')
axes[0].xaxis.set_major_formatter(formatter)
axes[0].set_xlabel('')
axes[0].set_ylabel('')

# Menambahkan Label Angka di Ujung Bar Top 10
for container in axes[0].containers:
    # Buat list label yang sudah diformat
    labels = [format_label_rupiah(x) for x in container.datavalues]
    axes[0].bar_label(container, labels=labels, padding=5, fontsize=10, fontweight='bold')

# Perluas batas kanan agar label tidak terpotong
max_omset_top = store_perf.head(10)['Omset_Paket'].max()
axes[0].set_xlim(right=max_omset_top * 1.15) 


# GRAFIK 2: BOTTOM 10 ===
sns.barplot(
    data=store_perf.tail(10), 
    x='Omset_Paket', 
    y='Nama Toko', 
    palette='Reds_r', 
    ax=axes[1]
)
axes[1].set_title('⚠️ 10 Toko dengan Performa Terendah (Omset)', fontsize=14, fontweight='bold')
axes[1].xaxis.set_major_formatter(formatter)
axes[1].set_xlabel('Total Omset')
axes[1].set_ylabel('')

# Menambahkan Label Angka di Ujung Bar Bottom 10
for container in axes[1].containers:
    labels = [format_label_rupiah(x) for x in container.datavalues]
    axes[1].bar_label(container, labels=labels, padding=5, fontsize=10, color='black')

# Perluas batas kanan agar label tidak terpotong
max_omset_bottom = store_perf.tail(10)['Omset_Paket'].max()
# Handle khusus jika max omset bottom sangat kecil (biar tidak error visual)
if max_omset_bottom > 0:
    axes[1].set_xlim(right=max_omset_bottom * 1.2) 

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\4205212972.py:19: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\4205212972.py:43: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\4205212972.py:66: UserWarning:
#
# Glyph 127942 (\N{TROPHY}) missing from font(s) Arial.
#
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\4205212972.py:66: UserWarning:
#
# Glyph 9888 (\N{WARNING SIGN}) missing from font(s) Arial.
#
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\4205212972.py:66: UserWarning:
#
# Glyph 65039 (\N{VARIATION SELECTOR-16}) missing from font(s) Arial.
#
# c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning:
#
# Glyph 127942 (\N{TROPHY}) missing from font(s) Arial.
#
# c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning:
#
# Glyph 9888 (\N{WARNING SIGN}) missing from font(s) Arial.
#
# c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning:
#
# Glyph 65039 (\N{VARIATION SELECTOR-16}) missing from font(s) Arial.

# %% [markdown]
# **Insight :**
# 1. Toko yang memiliki pendapatan tertinggi murni dalam top up kartu secara berturut turut ialah R067 Karawang, R105 Parung, R099 Garut, R079 Makassar 3, R125 Jatinegara, R066 Padang, RB20 Denpasar, R077 Bukittinggi, R041 Siantar,dan RB28 Kudus.
# 2. Toko yang memiliki pendapatan terendah murni dalam top up kartu secara berturut turut ialah R021 Bekasi, R119 Dinoyo, R029 Tanjung Priuk, ZD15 Bali Batu Bulan, 098 Kediri, RB12 Cimahi, R081 Bontang, R051 Balikpapan, ZD44 Ponorogo, dan ZD37 Samarinda.

# %% [markdown]
# **2. Paket dengan 'Nominal_Grup' mana yang memiliki performa terbaik dan terburuk dalam dua tahun terakhir**

# %%
# Fungsi Helper untuk Label Angka Ringkas ---
def format_label_rupiah(x):
    if x >= 1e9:
        return f'Rp {x/1e9:.1f} M'  # Miliar
    elif x >= 1e6:
        return f'Rp {x/1e6:.0f} Jt' # Juta
    elif x >= 1e3:
        return f'Rp {x/1e3:.0f} Rb' # Ribu (jika nominal kecil)
    else:
        return f'Rp {x:,.0f}'

# Proses Data ---
# Ganti 'Lainnya' menjadi 'Kiddie Zone'
df_clean['Nominal_Grup'] = df_clean['Nominal_Grup'].replace('Lainnya', 'Kiddie Zone')

# Agregasi Ulang
df_nominal = df_clean.groupby('Nominal_Grup')['Omset_Paket'].sum().sort_values(ascending=False).reset_index()

# Plotting ---
fig, axes = plt.subplots(1, 2, figsize=(18, 7)) # Tinggi ditambah sedikit agar label lega

#  Nominal Grup Terbaik (Top 5)
sns.barplot(
    data=df_nominal.head(5), 
    x='Nominal_Grup', 
    y='Omset_Paket', 
    palette='Blues_r', 
    ax=axes[0]
)
axes[0].set_title('Q3: Nominal Grup Performa Terbaik', fontsize=14, fontweight='bold')
axes[0].yaxis.set_major_formatter(formatter)
axes[0].set_xlabel('')
axes[0].set_ylabel('Total Omset')

# Tambahkan Label Angka (Top 5)
for container in axes[0].containers:
    # Buat list label format pendek
    labels = [format_label_rupiah(x) for x in container.datavalues]
    axes[0].bar_label(container, labels=labels, padding=3, fontsize=10, fontweight='bold')

# Atur batas atas Y agar label tidak kepotong
max_top = df_nominal.head(5)['Omset_Paket'].max()
axes[0].set_ylim(top=max_top * 1.15)


# GRAFIK 2: Nominal Grup Terendah (Bottom 5)
sns.barplot(
    data=df_nominal.tail(5), 
    x='Nominal_Grup', 
    y='Omset_Paket', 
    palette='Reds_r', 
    ax=axes[1]
)
axes[1].set_title('Q4: Nominal Grup Performa Terendah', fontsize=14, fontweight='bold')
axes[1].yaxis.set_major_formatter(formatter)
axes[1].set_xlabel('')
axes[1].set_ylabel('')

# Tambahkan Label Angka (Bottom 5)
for container in axes[1].containers:
    labels = [format_label_rupiah(x) for x in container.datavalues]
    axes[1].bar_label(container, labels=labels, padding=3, fontsize=10)

# Atur batas atas Y agar label tidak kepotong
max_bottom = df_nominal.tail(5)['Omset_Paket'].max()
if max_bottom > 0:
    axes[1].set_ylim(top=max_bottom * 1.2)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\1848290448.py:23: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\1848290448.py:47: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# **Insight :**
# 1. Nominal Top Up tertinggi pada transaksi berturut - turut ialah 50 ribu, 100 ribu, Kiddie Zone (tanpa nominal), 500 ribu, dan 30 ribu.
# 2. Nominal Top Up terendah pada transaksi berturut - turut ialah 75 ribu, 65 ribu, 15 ribu, 120 ribu, dan 5 ribu.

# %%
# --- AGREGASI DATA KATEGORI ---
df_kategori = df_clean.groupby('Kategori_Paket')['Omset_Paket'].sum().sort_values(ascending=False).reset_index()

# --- PLOTTING Q7 & Q8 ---
fig, axes = plt.subplots(2, 1, figsize=(14, 14)) # Disusun Atas-Bawah agar muat

# Q7: Top 10 Kategori Paket Terbaik
sns.barplot(data=df_kategori.head(10), x='Omset_Paket', y='Kategori_Paket', palette='Blues_r', ax=axes[0])
axes[0].set_title('Q7: Top 10 Kategori Paket Performa Terbaik', fontsize=14, fontweight='bold')
axes[0].xaxis.set_major_formatter(formatter)
axes[0].set_ylabel('')
axes[0].set_xlabel('')

# Q8: Top 10 Kategori Paket Terendah
sns.barplot(data=df_kategori.tail(10), x='Omset_Paket', y='Kategori_Paket', palette='Reds_r', ax=axes[1])
axes[1].set_title('Q8: 10 Kategori Paket Performa Terendah', fontsize=14, fontweight='bold')
axes[1].xaxis.set_major_formatter(formatter)
axes[1].set_ylabel('')
axes[1].set_xlabel('Total Omset')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\1405079277.py:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5008\1405079277.py:15: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# **3. Bagaimana komparasi Omset seluruh paket 2024 vs 2025?**

# %%
# ================= 1. PERSIAPAN DATA =================
# Pastikan format tanggal benar
df_clean['Tanggal'] = pd.to_datetime(df_clean['Tanggal'])

# Ambil Tahun dan Bulan
df_clean['Tahun'] = df_clean['Tanggal'].dt.year.astype(str)
df_clean['Bulan_Urut'] = df_clean['Tanggal'].dt.month
df_clean['Nama_Bulan'] = df_clean['Tanggal'].dt.strftime('%B')

# Filter Data hanya 2024 & 2025 (jika ada data tahun lain)
df_comp = df_clean[df_clean['Tahun'].isin(['2024', '2025'])].copy()

# ================= 2. ANALISIS 1: TOTAL OMSET TAHUNAN =================
print("--- KOMPARASI TOTAL OMSET (Yearly) ---")
df_yearly = df_comp.groupby('Tahun')['Omset_Paket'].sum().reset_index()

# Hitung Pertumbuhan (Growth)
omset_2024 = df_yearly[df_yearly['Tahun']=='2024']['Omset_Paket'].sum()
omset_2025 = df_yearly[df_yearly['Tahun']=='2025']['Omset_Paket'].sum()
growth = ((omset_2025 - omset_2024) / omset_2024) * 100

print(f"Total 2024: Rp {omset_2024:,.0f}")
print(f"Total 2025: Rp {omset_2025:,.0f}")
print(f"Pertumbuhan (YoY): {growth:.2f}%")

# Visualisasi Bar Chart Sederhana
fig_total = px.bar(
    df_yearly, 
    x='Tahun', 
    y='Omset_Paket',
    text_auto='.2s',
    title=f'Total Omset 2024 vs 2025 (Growth: {growth:.2f}%)',
    color='Tahun',
    color_discrete_map={'2024': '#bdc3c7', '2025': '#27ae60'} # 2024 Abu, 2025 Hijau
)
fig_total.update_layout(showlegend=False)
fig_total.show()

# ================= 3. ANALISIS 2: TREN BULANAN + DATA LABELS =================
print("\n--- KOMPARASI TREN BULANAN (YoY) ---")

# 1. Grouping Data
df_trend = df_comp.groupby(['Tahun', 'Bulan_Urut', 'Nama_Bulan'])['Omset_Paket'].sum().reset_index()
df_trend = df_trend.sort_values(['Tahun', 'Bulan_Urut'])

# 2. Buat Kolom Label yang Cantik (Singkatan Milyar/Juta)
def format_label_chart(nilai):
    if nilai >= 1_000_000_000:
        return f"{nilai/1_000_000_000:.1f}M" # Contoh: 1.2M (Milyar)
    elif nilai >= 1_000_000:
        return f"{nilai/1_000_000:.0f}jt"   # Contoh: 500jt
    else:
        return f"{nilai/1_000:.0f}rb"

df_trend['Label_Text'] = df_trend['Omset_Paket'].apply(format_label_chart)

# 3. Visualisasi Line Chart dengan Label
fig_trend = px.line(
    df_trend,
    x='Nama_Bulan',
    y='Omset_Paket',
    color='Tahun',
    markers=True,
    text='Label_Text',  # <--- INI KUNCINYA: Menampilkan teks dari kolom Label_Text
    title='Tren Omset Bulanan: 2024 vs 2025',
    color_discrete_map={'2024': 'gray', '2025': 'green'}
)

# 4. Atur Posisi Label agar Rapi
fig_trend.update_traces(
    textposition="top center",  # Taruh angka di atas titik
    textfont_size=11            # Ukuran font
)

# 5. Finishing Layout
fig_trend.update_layout(
    xaxis_title="Bulan",
    yaxis_title="Total Omset",
    legend_title="Tahun",
    yaxis=dict(showticklabels=False), # Opsional: Sembunyikan angka sumbu Y biar tidak double
    height=500 # Tinggi grafik
)

fig_trend.show()
# Out:
# --- KOMPARASI TOTAL OMSET (Yearly) ---
# Total 2024: Rp 107,153,829,466
# Total 2025: Rp 85,040,739,120
# Pertumbuhan (YoY): -20.64%
# --- KOMPARASI TREN BULANAN (YoY) ---

# %% [markdown]
# * Berdasarkan omset top up kartu, terjadi penurunan omset sebesar -28,45%. Total omset top up pada 69 toko aktif pada tahun 2024 yaitu Rp 107,153,829,466 turun menjadi Rp 85,040,739,120 sebesar -20.64%.
#
# * Terjadi peak pada bulan April di tahun 2024 sebesar 18,08 M dan Maret di tahun 2025 sebesar 13,12 M dan April di tahun 2025 sebesar 12,81 M.

# %% [markdown]
# Save df_clean ke excel

# %%
# ================= SAVE TO EXCEL =================
nama_file_output = "CLEAN_DATA_TRANSAKSI_FINAL.xlsx"

print(f"💾 Sedang menyimpan data ke {nama_file_output}...")

# Simpan ke Excel tanpa menyertakan index (nomor baris 0,1,2..)
df_clean.to_excel(nama_file_output, index=False)

print("✅ BERHASIL! File sudah tersimpan.")
print(f"Total Baris Data: {len(df_clean)}")
print(f"Kolom Tersedia: {list(df_clean.columns)}")
# Out:
# 💾 Sedang menyimpan data ke CLEAN_DATA_TRANSAKSI_FINAL.xlsx...
# ✅ BERHASIL! File sudah tersimpan.
# Total Baris Data: 36949
# Kolom Tersedia: ['Folder_Asal', 'Nama_Toko_Internal', 'Tahun', 'Bulan', 'Tipe_Kartu', 'Paket', 'Frekuensi', 'Total_Sales', 'Masuk_Kredit', 'Omset_Paket', 'Bulan_Angka', 'Tanggal', 'Nominal_Grup', 'Tipe_Grup', 'Kategori_Paket', 'Bulan_Urut', 'Nama_Bulan']
